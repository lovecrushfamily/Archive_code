# %% [markdown]
# ## Video Processing
#
# **Task**
#
# - *Extract the frame has teacher inside*

# %%
import cv2
import os
import matplotlib.pyplot as plt


video_path = "Ch05_CH 05_2008.avi"
output_folder = "frames"
os.makedirs(output_folder, exist_ok=True)

cap = cv2.VideoCapture(video_path)
frame_id = 0

# %%
# Open video
cap = cv2.VideoCapture(video_path)
if not cap.isOpened():
	raise SystemExit(f"Cannot open video: {video_path}")

fps = cap.get(cv2.CAP_PROP_FPS)
frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
duration_sec = frame_count / fps if fps > 0 else None

print(f"VIDEO INFO:\n  path: {video_path}\n  fps: {fps}\n  frames: {frame_count}\n  size: {width}x{height}\n  duration (s): {duration_sec}")
# Out:
# VIDEO INFO:
#   path: Ch05_CH 05_2008.avi
#   fps: 25.0
#   frames: 15831
#   size: 1920x1080
#   duration (s): 633.24

# %% [markdown]
# ### *Teacher frames*
#
# - *Manually capture the frames has teacher inside*
#
# - *Turn the second has teach into frame'th*

# %%
# while True:
#     ret, frame = cap.read()
#     if not ret:
#         break

#     if frame_id % 10 == 0:
#         cv2.imwrite(f"{output_folder}/frame_{frame_id:06d}.jpg", frame)
#     frame_id += 1

# cap.release()
# print("Done!")

# %%
[8:33:06 - 8:38:56] [8:39:58 - 8:41:10]
# Out:
# 'FFMPEG'

# %%
# Out:
# VIDEO INFO:
#   path: Ch05_CH 05_2008.avi
#   fps: 25.0
#   frames: 15831
#   size: 1920x1080
#   duration (s): 633.24
