# %% [markdown]
# ## Video Processing
#
# **Task**
#
# - *Extract the frame has teacher inside*

# %%
import cv2
import os
import matplotlib.pyplot as plt


video_path = "Ch05_CH 05_2008.avi"
output_folder = "frames"
os.makedirs(output_folder, exist_ok=True)

cap = cv2.VideoCapture(video_path)
frame_id = 0

# %%
# Open video
cap = cv2.VideoCapture(video_path)
if not cap.isOpened():
	raise SystemExit(f"Cannot open video: {video_path}")

fps = cap.get(cv2.CAP_PROP_FPS)
frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
duration_sec = frame_count / fps if fps > 0 else None

print(f"VIDEO INFO:\n  path: {video_path}\n  fps: {fps}\n  frames: {frame_count}\n  size: {width}x{height}\n  duration (s): {duration_sec}")
# Out:
# VIDEO INFO:
#   path: Ch05_CH 05_2008.avi
#   fps: 25.0
#   frames: 15831
#   size: 1920x1080
#   duration (s): 633.24

# %% [markdown]
# ### *Teacher frames*
#
# - *Manually capture the frames has teacher inside*
#
# - *Turn the second has teach into frame'th*

# %%
# None: 		[0:0 - 1:00] 				[4:50 - 7:49]				[9:00 - 10:33]
# Teacher: 			 		[1:00 - 4:50] 				 [7:50 - 9:00]

# %%
import cv2
import os

# === CHANGE ONLY THIS LINE ===
video_path = 'Ch05_CH 05_2008.avi'   # Example: 'video1.mp4' or full path like 'D:/folder/video.mp4'
# =============================

# Create folder to save frames
output_folder = 'teacher_frames'
os.makedirs(output_folder, exist_ok=True)

# Open video
cap = cv2.VideoCapture(video_path)
if not cap.isOpened():
    print("Error: Cannot open video. Check the file path!")
    exit()

# Video info
fps = cap.get(cv2.CAP_PROP_FPS)
total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
duration = total_frames / fps
print(f"Video loaded: {duration:.1f} seconds, {fps:.1f} fps")

# Define teacher segments in seconds
teacher_segments = [
    (60, 290),    # 1:00 to 4:50
    (470, 540)    # 7:50 to 9:00
]

# Convert to frame numbers
segments_in_frames = []
for start_sec, end_sec in teacher_segments:
    start_frame = int(start_sec * fps)
    end_frame = int(end_sec * fps)
    segments_in_frames.append((start_frame, end_frame))

# Extract frames
saved_count = 0
frame_step = 10  # as you requested
current_frame_idx = 0

while True:
    ret, frame = cap.read()
    if not ret:
        break
    
    # Check if current frame is inside any teacher segment
    in_teacher_time = any(start <= current_frame_idx <= end 
                          for start, end in segments_in_frames)
    
    if in_teacher_time and (current_frame_idx % frame_step == 0):
        filename = f"{output_folder}/frame_{saved_count:04d}.jpg"
        cv2.imwrite(filename, frame)
        saved_count += 1
        print(f"Saved {filename}")
    
    current_frame_idx += 1

cap.release()
print(f"\nDone! Extracted {saved_count} frames.")
print(f"Check the folder: {output_folder}")
# Out:
# Video loaded: 633.2 seconds, 25.0 fps
# Saved teacher_frames/frame_0000.jpg
# Saved teacher_frames/frame_0001.jpg
# Saved teacher_frames/frame_0002.jpg
# Saved teacher_frames/frame_0709.jpg
# Saved teacher_frames/frame_0710.jpg
# Saved teacher_frames/frame_0711.jpg
# Saved teacher_frames/frame_0712.jpg
# Saved teacher_frames/frame_0713.jpg
# Saved teacher_frames/frame_0714.jpg
# Saved teacher_frames/frame_0715.jpg
# Saved teacher_frames/frame_0716.jpg
# Saved teacher_frames/frame_0717.jpg
# Saved teacher_frames/frame_0718.jpg
# Saved teacher_frames/frame_0719.jpg
# Saved teacher_frames/frame_0720.jpg
# Saved teacher_frames/frame_0721.jpg
# Saved teacher_frames/frame_0722.jpg
# Saved teacher_frames/frame_0723.jpg
# Saved teacher_frames/frame_0724.jpg
# Saved teacher_frames/frame_0725.jpg
# Saved teacher_frames/frame_0726.jpg
# Saved teacher_frames/frame_0727.jpg
# Saved teacher_frames/frame_0728.jpg
# Saved teacher_frames/frame_0729.jpg
# Saved teacher_frames/frame_0730.jpg
# Saved teacher_frames/frame_0731.jpg
# Saved teacher_frames/frame_0732.jpg
# Saved teacher_frames/frame_0733.jpg
# Saved teacher_frames/frame_0734.jpg
# Saved teacher_frames/frame_0735.jpg
# Saved teacher_frames/frame_0736.jpg
# Saved teacher_frames/frame_0737.jpg
# Saved teacher_frames/frame_0738.jpg
# Saved teacher_frames/frame_0739.jpg
# Saved teacher_frames/frame_0740.jpg
# Saved teacher_frames/frame_0741.jpg
# Saved teacher_frames/frame_0742.jpg
# Saved teacher_frames/frame_0743.jpg
# Saved teacher_frames/frame_0744.jpg
# Saved teacher_frames/frame_0745.jpg
# Saved teacher_frames/frame_0746.jpg
# Saved teacher_frames/frame_0747.jpg
# Saved teacher_frames/frame_0748.jpg
# Saved teacher_frames/frame_0749.jpg
# Saved teacher_frames/frame_0750.jpg
# Saved teacher_frames/frame_0751.jpg
#
# Done! Extracted 752 frames.
# Check the folder: teacher_frames

# %%
import cv2
import mediapipe as mp
import os

mp_face = mp.solutions.face_detection
mp_hands = mp.solutions.hands

with mp_face.FaceDetection(min_detection_confidence=0.5) as face_detection, \
     mp_hands.Hands(min_detection_confidence=0.5) as hands:

    cap = cv2.VideoCapture('video_path.mp4')
    frame_count = 0
    saved_count = 0

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret: break

        frame_count += 1
        if frame_count % 5 != 0:  # Lấy mỗi 5 frame
            continue

        # Phát hiện khuôn mặt + tay
        results_face = face_detection.process(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
        results_hand = hands.process(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))

        if results_face.detections:  # Có khuôn mặt → có thể là giáo viên
            for detection in results_face.detections:
                # Lưu frame + ghi nhãn (sau này đẩy lên Roboflow)
                cv2.imwrite(f'frames/teacher_{saved_count}.jpg', frame)
                saved_count += 1
                print(f"Saved frame {saved_count}")
                break  # chỉ cần 1 khuôn mặt là đủ
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import mediapipe as ma
#
# ModuleNotFoundError: No module named 'mediapipe'
